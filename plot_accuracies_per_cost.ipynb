# %%
hifi_cheap_bp = {-3: 0.971284, -4: 0.971455, -5: 0.971743, -10: 0.971762, -15: 0.971353, -20: 0.971508, -50: 0.97521, -100: 0.971349}
hifi_expensive_bp = {-20: 0.971066, -50: 0.972057, -100: 0.973718, -200: 0.971845, -500: 0.972766, -1000: 0.976365, -1500: 0.976559, -10000: 0.980891}
hifi_cheap_node = {-3: 0.955941, -4: 0.95596, -5: 0.955971, -10: 0.95596, -15: 0.955935, -20: 0.955936, -50: 0.955889, -100: 0.955914}
hifi_expensive_node = {-20: 0.956172, -50: 0.958436, -100: 0.961005, -200: 0.965003, -500: 0.971143, -1000: 0.977315, -1500: 0.980494, -10000: 0.992424}

ont_cheap_bp = {-3: 0.979643, -4: 0.980321, -5: 0.980329, -10: 0.980449, -15: 0.980492, -20: 0.980371, -50: 0.980347, -100: 0.980337}
ont_expensive_bp = {-20: 0.980612, -50: 0.980766, -100: 0.980232, -200: 0.980949, -500: 0.980969, -1000: 0.980969, -1500: 0.98098, -10000: 0.98098}
ont_cheap_node = {-3: 0.99114, -4: 0.991133, -5: 0.991154, -10: 0.991205, -15: 0.991239, -20: 0.99123, -50: 0.991155, -100: 0.991157}
ont_expensive_node = {-20: 0.991886, -50: 0.992732, -100: 0.993438, -200: 0.994063, -500: 0.995139, -1000: 0.995139, -1500: 0.995528, -10000: 0.995528}

# %%
# Extract keys and values for plotting
hifi_cheap_keys = list(hifi_cheap_bp.keys())
hifi_cheap_values = list(hifi_cheap_bp.values())

hifi_cheap_node_keys = list(hifi_cheap_node.keys())
hifi_cheap_node_values = list(hifi_cheap_node.values())

ont_cheap_keys = list(ont_cheap_bp.keys())
ont_cheap_values = list(ont_cheap_bp.values())

ont_cheap_node_keys = list(ont_cheap_node.keys())
ont_cheap_node_values = list(ont_cheap_node.values())

ont_cheap_keys = list(ont_cheap_bp.keys())
ont_cheap_values = list(ont_cheap_bp.values())

# %%
hifi_expensive_keys = list(hifi_expensive_bp.keys())
hifi_expensive_values = list(hifi_expensive_bp.values())

hifi_expensive_node_keys = list(hifi_expensive_node.keys())
hifi_expensive_node_values = list(hifi_expensive_node.values())

ont_expensive_keys = list(ont_expensive_bp.keys())
ont_expensive_values = list(ont_expensive_bp.values())

ont_expensive_node_keys = list(ont_expensive_node.keys())
ont_expensive_node_values = list(ont_expensive_node.values())

# %%
# Plot bp and node accuracies per both cheap and expensive cost, for hifi, in symmetric log-scale
import matplotlib.pyplot as plt
import matplotlib as mpl
from pyfonts import load_google_font

font_path = load_google_font("Source Sans 3")

mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.size': 14})
mpl.rcParams['font.family'] = 'Source Sans 3'

# If font_path is a FontProperties object, get the actual path
if hasattr(font_path, 'get_file'):
    mpl.font_manager.fontManager.addfont(font_path.get_file())
else:
    mpl.font_manager.fontManager.addfont(font_path)

plt.figure(figsize=(10, 5))
plt.plot(hifi_cheap_keys, hifi_cheap_values, marker='o', label='Cheap (bp)')
plt.plot(hifi_cheap_node_keys, hifi_cheap_node_values, marker='^', label='Cheap (node)')
plt.plot(hifi_expensive_keys, hifi_expensive_values, marker='s', label='Expensive (bp)')
plt.plot(hifi_expensive_node_keys, hifi_expensive_node_values, marker='D', label='Expensive (node)')
plt.xlabel('Cost (symmetric log-scale)')
plt.ylabel('Accuracy')
plt.legend()
plt.xscale('symlog')
plt.yticks(plt.yticks()[0][::2])  # Show every other tick
plt.savefig("../hifi_accuracies_per_cost.svg")
plt.show()

# %%
# Plot bp and node accuracies per both cheap and expensive cost, for ont, in symmetric log-scale
import matplotlib.pyplot as plt
import matplotlib as mpl
from pyfonts import load_google_font

font_path = load_google_font("Source Sans 3")

mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
plt.rcParams.update({'font.size': 14})
mpl.rcParams['font.family'] = 'Source Sans 3'

# If font_path is a FontProperties object, get the actual path
if hasattr(font_path, 'get_file'):
    mpl.font_manager.fontManager.addfont(font_path.get_file())
else:
    mpl.font_manager.fontManager.addfont(font_path)

plt.figure(figsize=(10, 5))
plt.plot(ont_cheap_keys, ont_cheap_values, marker='o', label='Cheap (bp)')
plt.plot(ont_cheap_node_keys, ont_cheap_node_values, marker='^', label='Cheap (node)')
plt.plot(ont_expensive_keys, ont_expensive_values, marker='s', label='Expensive (bp)')
plt.plot(ont_expensive_node_keys, ont_expensive_node_values, marker='D', label='Expensive (node)')
plt.xlabel('Cost (symmetric log-scale)')
plt.ylabel('Accuracy')
plt.legend(loc='upper right', bbox_to_anchor=(1, 1.1))
plt.xscale('symlog')
plt.yticks(plt.yticks()[0][::2])  # Show every other tick
plt.savefig("../ont_accuracies_per_cost.svg")
plt.show()
